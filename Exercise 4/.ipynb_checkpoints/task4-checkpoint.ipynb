# %%
import time
import numpy as np
import tensorflow as tf
from tensorflow.contrib.slim import fully_connected as fc
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
train_set = np.load('FireEvac_train_set.npy')
test_set = np.load('FireEvac_test_set.npy')

num_sample = train_set.shape[0]
input_dim = train_set[0].shape[0]
w = h = int(np.sqrt(input_dim))

# %%
max = 0
for i, j in train_set:
    if max < i:
        max = i
    if max < j:
        max = j

print(max)
train_set /= max
test_set /= max
# Out:
# 188.49331237472774

# %%
plt.figure(figsize = (14, 14))
plt.hist2d((train_set)[:,0], (train_set)[:,1], bins=(200, 200), cmap=plt.cm.jet)
plt.show

plt.figure(figsize = (14, 14))
plt.hist2d((test_set)[:,0], (test_set)[:,1], bins=(200, 200), cmap=plt.cm.jet)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize = (14, 14))
plt.scatter(train_set*max, train_set*max)
plt.title("train")

plt.show()

plt.figure(figsize = (14, 14))
plt.scatter(test_set*max, test_set*max)
plt.title("test")

plt.show()

# %%
class VariantionalAutoencoder(object):

    def __init__(self, learning_rate=1e-3, batch_size=256, n_z=2):
        self.learning_rate = learning_rate
        self.batch_size = batch_size
        self.n_z = n_z

        self.build()

        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())

    def build(self):
        tf.reset_default_graph()
        self.x = tf.placeholder(
            name='x', dtype=tf.float32, shape=[None, input_dim])

        #2 fc with relu activation functions for encoding
        f1 = fc(self.x, 2, scope='enc_fc1', activation_fn=tf.nn.relu)
        #f2 = fc(f1, 64, scope='enc_fc2', activation_fn=tf.nn.relu)
        #f3 = fc(f1, 64, scope='enc_fc3', activation_fn=tf.nn.relu)
        
        #latent layer
        self.z_mu = fc(f1, self.n_z, scope='enc_fc4_mu', activation_fn=None)
        self.z_log_sigma_sq = fc(f1, self.n_z, scope='enc_fc4_sigma', activation_fn=None)
        eps = tf.random_normal(shape=tf.shape(self.z_log_sigma_sq), mean=0, stddev=1, dtype=tf.float32)
        self.z = self.z_mu + tf.sqrt(tf.exp(self.z_log_sigma_sq)) * eps
        
        #2 fc with activation function for decoding
        g1 = fc(self.z, 2, scope='dec_fc1', activation_fn=tf.nn.relu)
        #g2 = fc(g1, 64, scope='dec_fc2', activation_fn=tf.nn.relu)
        #g3 = fc(g1, 16, scope='dec_fc3', activation_fn=tf.nn.relu)
        self.x_hat = fc(g1, input_dim, scope='dec_fc4', activation_fn=tf.nn.sigmoid)

        epsilon = 1e-10
        recon_loss = -tf.reduce_sum(self.x * tf.log(epsilon+self.x_hat) + (1-self.x) * tf.log(epsilon+1-self.x_hat), axis=1)
        self.recon_loss = tf.reduce_mean(recon_loss)

        latent_loss = -0.5 * tf.reduce_sum(1 + self.z_log_sigma_sq - tf.square(self.z_mu) - tf.exp(self.z_log_sigma_sq), axis=1)
        self.latent_loss = tf.reduce_mean(latent_loss)

        #ELBO
        self.total_loss = self.recon_loss + self.latent_loss
        self.train_op = tf.train.AdamOptimizer(learning_rate=self.learning_rate).minimize(self.total_loss)
        
        self.losses = {
            'recon_loss': self.recon_loss,
            'latent_loss': self.latent_loss,
            'total_loss': self.total_loss,
        }        
        return

    def run_single_step(self, x):
        _, losses = self.sess.run([self.train_op, self.losses], feed_dict={self.x: x})
        return losses

    # x -> x_hat
    def reconstructor(self, x):
        x_hat = self.sess.run(self.x_hat, feed_dict={self.x: x})
        return x_hat

    # z -> x
    def generator(self, z):
        x_hat = self.sess.run(self.x_hat, feed_dict={self.z: z})
        return x_hat
    
    # x -> z
    def transformer(self, x):
        z = self.sess.run(self.z, feed_dict={self.x: x})
        return z

# %%
def trainer(model_class, learning_rate=1e-3, batch_size=256, num_epoch=5, n_z=2, log_step=1):
    model = model_class(learning_rate=learning_rate, batch_size=batch_size, n_z=n_z)

    elbo = []
    recon = []
    latent = []
    for epoch in range(num_epoch):
        start_time = time.time()
        
        for iter in range(num_sample // batch_size):
            
            batch = train_set[iter*batch_size:(iter+1)*batch_size]
            losses = model.run_single_step(batch)
            
        end_time = time.time()
        elbo.append(losses["total_loss"])
        recon.append(losses["recon_loss"])
        latent.append(losses["latent_loss"])
        
        if epoch % log_step == 0:
            log_str = '[Epoch {}] '.format(epoch)
            for k, v in losses.items():
                log_str += '{}: {:.3f}  '.format(k, v)
            log_str += '({:.3f} sec/epoch)'.format(end_time - start_time)
            print(log_str)
            
    print('Done!')

    plt.figure(figsize = (12, 12)) 
    plt.plot([e for e in range(num_epoch)], elbo, label = "ELBO")
    plt.plot([e for e in range(num_epoch)], recon, label = "Reconstruction Loss")
    plt.plot([e for e in range(num_epoch)], latent, label = "Latent Loss")
    plt.title("EPOCH VS ELBO")
    plt.legend()

    plt.show()
    
    return model

# %%
def test_transformation(model, test_set, batch_size=3000):
    
    assert model.n_z == 2
    batch = test_set[:batch_size]
    z = model.transformer(batch)
    plt.figure(figsize=(10, 8)) 
    plt.scatter(z[:, 0], z[:, 1], c=np.argmax(batch[1], 1), s=20)
    plt.colorbar()
    plt.grid()

# %%
def test_reconstruction(model, test_set, h=2, w=2, batch_size=3000):

    batch = test_set[:batch_size]
    x_reconstructed = model.reconstructor(batch)
    
    x_reconstructed *= max

    plt.figure(figsize = (14, 14))
    plt.scatter(x_reconstructed, x_reconstructed)
    plt.title("x_reconstructed")

    plt.show()
    
    
    plt.figure(figsize = (14, 14))
    plt.hist2d((x_reconstructed)[:,0], (x_reconstructed)[:,1], bins=(200, 200), cmap=plt.cm.jet)
    plt.show

# %%
def test_generation(model, z=None, h=2, w=2, batch_size=1000, plot=True):

    if z is None:
        z = np.random.normal(size=[batch_size, model.n_z])
    x_generated = model.generator(z)    

    x_generated *= max
    
    if plot:
        plt.figure(figsize = (14, 14))
        plt.scatter(x_generated, x_generated)
        plt.title("x_generated")
        plt.show()
        
        plt.figure(figsize = (14, 14))
        plt.hist2d((x_generated)[:,0], (x_generated)[:,1], bins=(200, 200), cmap=plt.cm.jet)
        plt.show
    return x_generated

# %%
print("dim=2 epoch=50")
model_vae = trainer(VariantionalAutoencoder, n_z=2, num_epoch=30)
#test_transformation(model_vae, test_set)
test_reconstruction(model_vae, test_set)
test_generation(model_vae)
# Out:
# dim=2 epoch=50
# WARNING:tensorflow:From c:\users\yalva\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\contrib\layers\python\layers\layers.py:1866: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# [Epoch 0] recon_loss: 1.410  latent_loss: 0.015  total_loss: 1.424  (0.179 sec/epoch)
# [Epoch 1] recon_loss: 1.415  latent_loss: 0.013  total_loss: 1.428  (0.012 sec/epoch)
# [Epoch 2] recon_loss: 1.400  latent_loss: 0.012  total_loss: 1.412  (0.012 sec/epoch)
# [Epoch 3] recon_loss: 1.405  latent_loss: 0.010  total_loss: 1.415  (0.009 sec/epoch)
# [Epoch 4] recon_loss: 1.398  latent_loss: 0.010  total_loss: 1.409  (0.015 sec/epoch)
# [Epoch 5] recon_loss: 1.386  latent_loss: 0.010  total_loss: 1.395  (0.022 sec/epoch)
# [Epoch 6] recon_loss: 1.390  latent_loss: 0.008  total_loss: 1.399  (0.015 sec/epoch)
# [Epoch 7] recon_loss: 1.380  latent_loss: 0.008  total_loss: 1.388  (0.010 sec/epoch)
# [Epoch 8] recon_loss: 1.374  latent_loss: 0.008  total_loss: 1.381  (0.008 sec/epoch)
# [Epoch 9] recon_loss: 1.350  latent_loss: 0.007  total_loss: 1.357  (0.016 sec/epoch)
# [Epoch 10] recon_loss: 1.379  latent_loss: 0.007  total_loss: 1.386  (0.013 sec/epoch)
# [Epoch 11] recon_loss: 1.379  latent_loss: 0.007  total_loss: 1.385  (0.016 sec/epoch)
# [Epoch 12] recon_loss: 1.366  latent_loss: 0.007  total_loss: 1.373  (0.010 sec/epoch)
# [Epoch 13] recon_loss: 1.371  latent_loss: 0.006  total_loss: 1.376  (0.008 sec/epoch)
# [Epoch 14] recon_loss: 1.352  latent_loss: 0.006  total_loss: 1.358  (0.010 sec/epoch)
# [Epoch 15] recon_loss: 1.338  latent_loss: 0.006  total_loss: 1.344  (0.019 sec/epoch)
# [Epoch 16] recon_loss: 1.360  latent_loss: 0.005  total_loss: 1.365  (0.017 sec/epoch)
# [Epoch 17] recon_loss: 1.348  latent_loss: 0.005  total_loss: 1.353  (0.016 sec/epoch)
# [Epoch 18] recon_loss: 1.350  latent_loss: 0.004  total_loss: 1.354  (0.026 sec/epoch)
# [Epoch 19] recon_loss: 1.335  latent_loss: 0.004  total_loss: 1.339  (0.011 sec/epoch)
# [Epoch 20] recon_loss: 1.349  latent_loss: 0.004  total_loss: 1.354  (0.015 sec/epoch)
# [Epoch 21] recon_loss: 1.336  latent_loss: 0.004  total_loss: 1.341  (0.013 sec/epoch)
# [Epoch 22] recon_loss: 1.341  latent_loss: 0.004  total_loss: 1.345  (0.013 sec/epoch)
# [Epoch 23] recon_loss: 1.331  latent_loss: 0.004  total_loss: 1.335  (0.012 sec/epoch)
# [Epoch 24] recon_loss: 1.335  latent_loss: 0.003  total_loss: 1.338  (0.008 sec/epoch)
# [Epoch 25] recon_loss: 1.339  latent_loss: 0.003  total_loss: 1.342  (0.010 sec/epoch)
# [Epoch 26] recon_loss: 1.331  latent_loss: 0.003  total_loss: 1.334  (0.013 sec/epoch)
# [Epoch 27] recon_loss: 1.328  latent_loss: 0.003  total_loss: 1.331  (0.013 sec/epoch)
# [Epoch 28] recon_loss: 1.325  latent_loss: 0.003  total_loss: 1.328  (0.019 sec/epoch)
# [Epoch 29] recon_loss: 1.324  latent_loss: 0.003  total_loss: 1.327  (0.014 sec/epoch)
# Done!
# array([[140.44049 ,  40.69003 ],
#        [106.95199 ,  89.855156],
#        [112.24144 ,  89.45895 ],
#        ...,
#        [111.35437 ,  89.52592 ],
#        [127.78089 ,  81.130325],
#        [119.613464,  88.89143 ]], dtype=float32)

# %%
num_people = 10
counter = 0

while counter < 1000:
    num_people += 1
    x_hat = test_generation(model_vae, batch_size=num_people, plot=False)
    counter = 0
    for i in range(num_people):
        if ((130 > x_hat[i][0] and x_hat[i][0] > 70) and (150 > x_hat[i][1] and x_hat[i][1] > 50)):
            counter += 1

print(num_people)
print(counter)
plt.figure(figsize = (14, 14))
plt.hist2d((x_hat)[:,0], (x_hat)[:,1], bins=(200,200), cmap=plt.cm.jet)
plt.show
# Out:
# 1464
# 1000
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#2:2:2 = 1079 / 1.399
#2:4:2 = 1386 / 1.5
#4:8:4 == 1103 / 1.393
